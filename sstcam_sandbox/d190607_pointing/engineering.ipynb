# %%
import astropy.units as u
from astropy.time import Time
import copy
import numpy as np
from os.path import abspath, dirname, join
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from astropy.coordinates import SkyCoord, AltAz, EarthLocation
from astroquery.vizier import Vizier
from ctapipe.instrument import CameraGeometry
from ctapipe.visualization import CameraDisplay
from ctapipe.coordinates import (
    GroundFrame,
    TiltedGroundFrame,
    NominalFrame,
    TelescopeFrame,
    CameraFrame,
    EngineeringCameraFrame,
)

# %%
# Define 2M transformation
from ctapipe.coordinates.camera_frame import CameraFrame, CartesianRepresentation, AffineTransform, frame_transform_graph

CAMERA_TO_ENGINEERING2M_MATRIX = np.array([
    [0, 1, 0],
    [-1, 0, 0],
    [0, 0, 1]
])
ENGINEERING2M_FRAME_TRANSFORM_OFFSET = CartesianRepresentation(0, 0, 0, unit=u.m)

ENGINEERING2M_TO_CAMERA_MATRIX = np.array([
    [0, -1, 0],
    [1, 0, 0],
    [0, 0, 1]
])


class Engineering2MCameraFrame(CameraFrame):
    pass

@frame_transform_graph.transform(AffineTransform, CameraFrame, Engineering2MCameraFrame)
def camera_to_engineering2M(from_coord, to_frame):
    return CAMERA_TO_ENGINEERING2M_MATRIX, ENGINEERING2M_FRAME_TRANSFORM_OFFSET

@frame_transform_graph.transform(AffineTransform, Engineering2MCameraFrame, CameraFrame)
def engineering2M_to_camera(from_coord, to_frame):
    return ENGINEERING2M_TO_CAMERA_MATRIX, ENGINEERING2M_FRAME_TRANSFORM_OFFSET

# %%
ss_image = np.load('/Users/Jason/Software/sstcam_sandbox/sstcam_sandbox/d190607_pointing/DracoIm.npy')

# %%
# Define pointing
location=EarthLocation.from_geodetic(lon=14.974609, lat=37.693267, height=1750)
obstime=Time("2019-05-09T01:37:54.728026")

altaz_frame = AltAz(location=location, obstime=obstime)

alt = 73.21 * u.deg
az = 0.5 * u.deg

telescope_pointing = SkyCoord(
    alt=alt, 
    az=az, 
    frame=altaz_frame,
)

# %%
focal_length = u.Quantity(2.15191, u.m)
#focal_length = u.Quantity(2.141, u.m)

camera_frame = CameraFrame(
    location=location,
    obstime=obstime,
    focal_length=focal_length,
    telescope_pointing=telescope_pointing,
)
engineering_frame = EngineeringCameraFrame(
    location=location,
    obstime=obstime,
    focal_length=focal_length,
    telescope_pointing=telescope_pointing,
)
engineering2M_frame = Engineering2MCameraFrame(
    location=location,
    obstime=obstime,
    focal_length=focal_length,
    telescope_pointing=telescope_pointing,
)

# %%
# Get pixel coordinates from TargetCalib
from target_calib import CameraConfiguration
camera_config = CameraConfiguration("1.1.0")
m = camera_config.GetMapping()

xpix = np.array(m.GetXPixVector()) * u.m
ypix = np.array(m.GetYPixVector()) * u.m
size = m.GetSize() * u.m
area = size**2
pix_area = np.full(xpix.size, area) * area.unit

engineering2M_camera_geom = CameraGeometry(
    "CHEC",
    pix_id=np.arange(xpix.size),
    pix_x=xpix,
    pix_y=ypix,
    pix_area=pix_area,
    pix_type='rectangular',
    frame=engineering2M_frame
)

# %%
# Get stars
vizier = Vizier(
    catalog='V/50',
    columns=['_RAJ2000', '_DEJ2000', 'Vmag', 'Name']
)
t = vizier.query_region(telescope_pointing, radius=5 * u.deg, catalog='V/50')[0]
t.sort("Vmag")
t = t[:5]
stars = SkyCoord(ra=t['_RAJ2000'], dec=t['_DEJ2000'], frame='icrs')

stars_cam = stars.transform_to(camera_frame)
stars_eng = stars.transform_to(engineering_frame)
stars_eng2M = stars.transform_to(engineering2M_frame)

# %%
fig, axs = plt.subplots(1, 3, constrained_layout=True, figsize=(12, 6))
display_camera = CameraDisplay(
    engineering2M_camera_geom, 
    ax=axs[0], 
    image=ss_image,
    title="Engineering2MCameraFrame",
    cmap='inferno'
)
display_camera.set_limits_minmax(-10, 100)
display_engineering = CameraDisplay(
    engineering2M_camera_geom.transform_to(camera_frame),
    ax=axs[1],
    image=ss_image,
    title="CameraFrame",
    cmap='inferno',
)
display_engineering.set_limits_minmax(-10, 100)
display_engineering = CameraDisplay(
    engineering2M_camera_geom.transform_to(engineering_frame),
    ax=axs[2],
    image=ss_image,
    title="EngineeringCameraFrame",
    cmap='inferno',
)
display_engineering.set_limits_minmax(-10, 100)

#axs[0].plot(stars_cam.x.value, stars_cam.y.value, 'wo', mfc='none', ms=25, mew=2)
#axs[1].plot(stars_eng.x.value, stars_eng.y.value, 'wo', mfc='none', ms=25, mew=2)

axs[0].plot(stars_eng2M.x.value, stars_eng2M.y.value, 'wo', mfc='none', ms=25, mew=2)
axs[1].plot(stars_cam.x.value, stars_cam.y.value, 'wo', mfc='none', ms=25, mew=2)
axs[2].plot(stars_eng.x.value, stars_eng.y.value, 'wo', mfc='none', ms=25, mew=2)
